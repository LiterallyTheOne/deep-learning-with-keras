# %% [markdown]
# # <div style="text-align: center; color: cyan">Final Assignment</div>

# %% [markdown]
# ## <div style="text-align: center; color: lime">Setup</div>

# %%
import os

os.environ["KERAS_BACKEND"] = "torch"

# %% [markdown]
# ## <div style="text-align: center; color: lime">Imports</div>

# %%
# Your code here

# %% [markdown]
# ## <div style="text-align: center; color: lime">Load the data</div>

# %%
# Your code here

# %% [markdown]
# ### <div style="text-align: center; color: lightsalmon">Show a batch of data</div>

# %%
# Your code here

# %% [markdown]
# ## <div style="text-align: center; color: lime">Make the model</div>

# %%
# Your code here

# %% [markdown]
# ### <div style="text-align: center; color: lightsalmon">Print the model's summary</div>

# %%
# Your code here

# %% [markdown]
# ## <div style="text-align: center; color: lime">Train the model</div>

# %% [markdown]
# ### <div style="text-align: center; color: lightsalmon">Define Tensorboard</div>

# %%
# Your code here

# %% [markdown]
# ### <div style="text-align: center; color: lightsalmon">Define EarlyStopping</div>

# %%
# Your code here

# %% [markdown]
# ### <div style="text-align: center; color: lightsalmon">Define ModelCheckpoint</div>

# %%
# Your code here

# %% [markdown]
# ### <div style="text-align: center; color: lightsalmon">Fit the model</div>

# %%
# Your code here

# %% [markdown]
# ## <div style="text-align: center; color: lime">Evalute the model</div>

# %%
# Your code here

# %% [markdown]
# ## <div style="text-align: center; color: lime">Plot the training procedure</div>

# %%
# Your code here

# %% [markdown]
# <p style="text-align: center; font-family: "Trebuchet MS", sans-serif; color: #888; font-size: 0.9em; margin-top: 2em; border-top: 1px solid #ccc; padding-top: 0.5em;">
#     @LiterallyTheOne — PhD Candidate in Artificial Intelligence
# </p>
#
# <div style="text-align: center">
# <a style="margin: 1em" href="https://literallytheone.github.io">https://literallytheone.github.io</a>
# </div>
